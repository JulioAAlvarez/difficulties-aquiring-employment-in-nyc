# %%
import seaborn as sns
import pandas as pd

df = pd.read_csv('NYC_Jobs_20260713.csv')

# %%
# Job posting over time decresing since 2020
# Find min max of  posting time column
# Distribution of job types.

# %%
num = df['Business Title']
num.mean
num.describe()
# Posting Date
# Post until
# Posting Updated
# Out:
# count                    2148
# unique                    841
# top       ACCOUNTABLE MANAGER
# freq                       30
# Name: Business Title, dtype: object

# %%
df['Title Code No'].value_counts(dropna=False)
# Out:
# Title Code No
# 56058    189
# 56057    110
# 21744    108
# 30087     67
# 10124     60
#         ...
# 92590      1
# 06405      1
# 06423      1
# 92406      1
# 60430      1
# Name: count, Length: 290, dtype: int64

# %%
df['Posting Type'].unique('External'=true, 'Internal'=false)
# print('Posting Type:', df[External].unique())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 df['Posting Type'].unique('External'==true, 'Internal'==false)
#       2 # print('Posting Type:', df[External].unique())
#
# NameError: name 'true' is not defined
